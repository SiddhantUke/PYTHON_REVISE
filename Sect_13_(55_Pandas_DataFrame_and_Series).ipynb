# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhantUke/PYTHON_REVISE/blob/main/Sect_13_(55_Pandas_DataFrame_and_Series).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas-DataFrame And Series
#
#
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
# FOR INSTALLATION OF PANDAS LIBRARY !

# !pip install pandas

# %%
import pandas as pd

# %%
## Series
##A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]

series=pd.Series(data)

print("Series \n",series)

print(type(series))


## One way that create a series from list !
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## Create a Series from dictionary

data = {'a':1, 'b':2, 'c':3}

series_dict=pd.Series(data)  ## S always must be capital !

print(series_dict) ##
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
## this is another way that is actually we can use series and all !

data = [10,20,30]

index = ['a','b','c']

pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
##

# %% [markdown]
# DATA FRAME !

# %%
## CREATE A DATA FRAME FROM DICTIONARY of list !

#Dataframe

data = {
    'Name' : ['Sidd', 'Kakarot', 'Uke'],
    'Age' : [25,30,45],
    'City': ['Bangalore','Japan', 'FLorida']

}
df1 = pd.DataFrame(data)

print(df1)
print(type(df1))
# Out:
#       Name  Age       City
# 0     Sidd   25  Bangalore
# 1  Kakarot   30      Japan
# 2      Uke   45    FLorida
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ---
#
#
# we can use any from this 2
# ---
# ---

# %%
## Create a Data Frame from the  list of dictionaries

data=[
    {'Name':'Krish','Age':32,'City':'Bangalore'},
    {'Name':'John','Age':34,'City':'Bangalore'},
    {'Name':'Bappy','Age':32,'City':'Bangalore'},
    {'Name':'JAck','Age':32,'City':'Bangalore'}

]
dff=pd.DataFrame(data)
print(dff)
print(type(dff))
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   34  Bangalore
# 2  Bappy   32  Bangalore
# 3   JAck   32  Bangalore
# <class 'pandas.core.frame.DataFrame'>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2c094c8-e325-4ab1-a4e0-4144c930ee9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2c094c8-e325-4ab1-a4e0-4144c930ee9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/Churn_Modelling.csv")
df.tail(5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
## Access Data  From the data frame !

df1
# Out:
#       Name  Age       City
# 0     Sidd   25  Bangalore
# 1  Kakarot   30      Japan
# 2      Uke   45    FLorida

# %%
df1['Name']
# Out:
# 0       Sidd
# 1    Kakarot
# 2        Uke
# Name: Name, dtype: object

# %%
df1.loc[0][1]
# Out:
# <ipython-input-44-3707322108>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df1.loc[0][1]
# np.int64(25)

# %%
##Accessing the Specified Element !


df1['City']
# Out:
# 0    Bangalore
# 1        Japan
# 2      FLorida
# Name: City, dtype: object

# %%
## Acessing Specified Element !

df1.at[0, 'Name']
# Out:
# 'Sidd'

# %%
df1.at[2, 'Age']
# Out:
# np.int64(45)

# %%
## Accesiing a specified element using iat

df1.iat[1,2]
# Out:
# 'Japan'

# %%
##

df1
# Out:
#       Name  Age       City
# 0     Sidd   25  Bangalore
# 1  Kakarot   30      Japan
# 2      Uke   45    FLorida

# %%
## LEts Perform Data Manipulation with Data Frame

## Adding a column
df1['Salary']=[50000,60000,70000]
df1
# Out:
#       Name  Age       City  Salary
# 0     Sidd   25  Bangalore   50000
# 1  Kakarot   30      Japan   60000
# 2      Uke   45    FLorida   70000

# %%
## Remove a Column !

df1.drop('salary')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-4072285471> in <cell line: 0>()
#       1 ## Remove a Column !
#       2
# ----> 3 df1.drop('salary')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
## Why is this because the axis value is Zero !

df1.drop('salary', axis=0) ## BAsically Checking in a Row Index !

## We have to convert that X = 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-3632120261> in <cell line: 0>()
#       1 ## Why is this because the axis value is Zero !
#       2
# ----> 3 df1.drop('salary', axis=0) ## BAsically Checking in a Row Index !
#       4
#       5 ## We have to convert that X = 1
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
df1.drop('Salary', axis=1)
# Out:
#       Name  Age       City
# 0     Sidd   25  Bangalore
# 1  Kakarot   30      Japan
# 2      Uke   45    FLorida

# %%
df1

## WHat Happend we Actually Drop it aas well !
 ## Temporary Saved

#  but

# for permanent save in dataframe we have another operation !

inplace = True

# %%
df1.drop('Salary', axis=1, inplace=True)

# %%
df1
# Out:
#       Name  Age       City
# 0     Sidd   25  Bangalore
# 1  Kakarot   30      Japan
# 2      Uke   45    FLorida

# %%
# Adding Age to the column

df1['Age'] = df1['Age']+1
df1
# Out:
#    Name  Age       City
# 0  Sidd   28  Bangalore
# 2   Uke   48    FLorida

# %%
##  Removed Based On Rows !

df1.drop(0)
# Out:
#   Name  Age     City
# 2  Uke   48  FLorida

# %%
df1.drop(0,inplace=True)
df1
# Out:
#   Name  Age     City
# 2  Uke   48  FLorida

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   43
# 1          2    15647311      Hill          608     Spain  Female   42
# 2          3    15619304      Onio          502    France  Female   43
# 3          4    15701354      Boni          699    France  Female   40
# 4          5    15737888  Mitchell          850     Spain  Female   44
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...
